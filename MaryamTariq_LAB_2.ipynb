# %% [markdown]
# <a href="https://colab.research.google.com/github/maryamtariqdev/Plant-Info-Agent/blob/main/MaryamTariq_LAB_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -U google-genai

# %%
from google import genai

client = genai.Client(api_key="Maryam API Key")

# %%
model = "gemini-3.6-flash"

# %%
print("Gemini Chatbot (type 'exit' to quit)\n")

while True:
    user_input = input("You: ")

    if user_input.lower() in ["exit", "quit", "bye"]:
        print("Chatbot: Goodbye")
        break

    response = client.models.generate_content(
        model="models/gemini-3.6-flash",
        contents=user_input
    )

    print("Chatbot:", response.text)
# Out:
# Gemini Chatbot (type 'exit' to quit)
#
# You: exit
# Chatbot: Goodbye
