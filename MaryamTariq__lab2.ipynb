# %% [markdown]
# <a href="https://colab.research.google.com/github/maryamtariqdev/Plant-Info-Agent/blob/main/MaryamTariq__lab2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q -U google-genai

from google import genai

# ========== HARD CODED SETTINGS ==========
API_KEY = "YOUR_GEMINI_API_KEY"  # <-- put your key here
MODEL = "gemini-2.5-flash"       # <-- you can change to gemini-2.5-pro
SYSTEM_PROMPT = "You are ChatGPT-style assistant powered by Gemini. Be helpful, concise, and friendly."
EXIT_WORDS = ["exit", "quit", "bye", "stop"]
# ==========================================

client = genai.Client(api_key=API_KEY)

chat = client.chats.create(
    model=MODEL,
    config=genai.types.GenerateContentConfig(
        system_instruction=SYSTEM_PROMPT
    )
)

print(f"Gemini Chatbot started | Model: {MODEL}")
print(f"Type one of {EXIT_WORDS} to stop.\n")

while True:
    user_input = input("You: ").strip()

    if user_input.lower() in EXIT_WORD
